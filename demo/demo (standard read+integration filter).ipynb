# %%
from vmk_spectrum3_wrapper.data import Data
from vmk_spectrum3_wrapper.device import Device
from vmk_spectrum3_wrapper.measurement_manager.filters import StandardIntegrationPreset

# %%
exposure = 10
capacity = 100

# %%
device = Device()
device = device.connect()

# %%
device = device.setup(
    exposure=exposure,
    capacity=capacity,
)

# %% [markdown]
# #### Calibrate `dark`

# %%
from vmk_spectrum3_wrapper.calibration import calibrate_dark


dark = calibrate_dark(
    device=device,
    exposure=exposure,
    capacity=100,
    bias=Data.load('bias.pkl'),
    show=True,
    save=True,
)

# %% [markdown]
# #### Read

# %%
n_times = 1
device = device.setup(
    n_times=n_times,
    exposure=exposure,
    capacity=capacity,
    filter=StandardIntegrationPreset(
        bias=Data.load('bias.pkl'),
        dark=Data.load('dark.pkl'),
    ),
)

# %%
data = device.read()
data.show()
